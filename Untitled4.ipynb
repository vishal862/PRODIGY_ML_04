# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d theeyeschico/indian-food-classification
# Out:
# ...
# 100% 1.67G/1.67G [01:23<00:00, 24.3MB/s]
# 100% 1.67G/1.67G [01:23<00:00, 21.5MB/s]

# %%
#unzip the file
import zipfile
zip_ref = zipfile.ZipFile('/content/indian-food-classification.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)
# Out:
# 2.13.0

# %%
# Create a list with the filepaths for training and testing and validation
train_dir = Path('../content/dataset/Dataset/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))

# %%
test_dir = Path('../content/test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
val_dir = Path('../content/dataset/Dataset/val')
val_filepaths = list(val_dir.glob(r'**/*.jpg'))

# %%
'''in this we are creating a function in which all the images that are converted into list format
will pass through this function and will extract the labels and create a series of filepath and labels
and after that we will concatinate them'''

def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures"""

  #extracting the labels from the images
    labels = [str(filepath[i]).split("/")[-2] for i in range(len(filepath))]

  #create a series of filepaths
    filepath = pd.Series(filepath, name='Filepath').astype(str)

   #create a series of filepaths
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)

    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 3987
#
# Number of different labels: 20
#
# Labels: ['kaathi_rolls' 'samosa' 'momos' 'kadai_paneer' 'idli' 'fried_rice'
#  'chapati' 'burger' 'dal_makhani' 'jalebi' 'pizza' 'chai' 'chole_bhature'
#  'pakode' 'pav_bhaji' 'butter_naan' 'paani_puri' 'kulfi' 'masala_dosa'
#  'dhokla']

# %%
train_df.head(5)
# Out:
#                                             Filepath         Label
# 0  ../content/dataset/Dataset/train/kaathi_rolls/...  kaathi_rolls
# 1    ../content/dataset/Dataset/train/samosa/241.jpg        samosa
# 2    ../content/dataset/Dataset/train/samosa/072.jpg        samosa
# 3     ../content/dataset/Dataset/train/momos/138.jpg         momos
# 4  ../content/dataset/Dataset/train/kadai_paneer/...  kadai_paneer

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows= 4, ncols=4, figsize=(8, 7),subplot_kw={'xticks': [], 'yticks': []})

'''here a enumerate is function which it iterates through a axes names subplot with keeeping the track of
indexes 'i and original subplot 'ax '''

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 3987 validated image filenames belonging to 20 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 1245 validated image filenames belonging to 20 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=0,
)
# Out:
# Found 585 validated image filenames belonging to 20 classes.

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False
# Out:
# ...
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
from tensorflow.keras.layers import Dropout
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(20, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 292s 2s/step - loss: 1.1469 - accuracy: 0.6800 - val_loss: 0.6350 - val_accuracy: 0.8129
# Epoch 2/5
# 125/125 [==============================] - 295s 2s/step - loss: 0.3423 - accuracy: 0.8989 - val_loss: 0.5038 - val_accuracy: 0.8466
# Epoch 3/5
# 125/125 [==============================] - 285s 2s/step - loss: 0.1986 - accuracy: 0.9426 - val_loss: 0.4488 - val_accuracy: 0.8554
# Epoch 4/5
# 125/125 [==============================] - 288s 2s/step - loss: 0.1180 - accuracy: 0.9669 - val_loss: 0.4760 - val_accuracy: 0.8627
# Epoch 5/5
# 125/125 [==============================] - 287s 2s/step - loss: 0.0588 - accuracy: 0.9877 - val_loss: 0.4058 - val_accuracy: 0.8787

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred1 = [labels[k] for k in pred]
pred1
# Out:
# 19/19 [==============================] - 34s 2s/step
# ['kadai_paneer',
#  'masala_dosa',
#  'kulfi',
#  'kadai_paneer',
#  'chapati',
#  'samosa',
#  'momos',
#  'kadai_paneer',
#  'chole_bhature',
#  'paani_puri',
#  'idli',
#  'chai',
#  'kadai_paneer',
#  'pizza',
#  'burger',
#  'kaathi_rolls',
#  'masala_dosa',
#  'chapati',
#  'kaathi_rolls',
#  'dhokla',
#  'kadai_paneer',
#  'chapati',
#  'pakode',
#  'pav_bhaji',
#  'kadai_paneer',
#  'kaathi_rolls',
#  'chai',
#  'dal_makhani',
#  'paani_puri',
#  'fried_rice',
#  'fried_rice',
#  'chapati',
#  'paani_puri',
#  'kulfi',
#  'momos',
#  'dal_makhani',
#  'chai',
#  'fried_rice',
#  'masala_dosa',
#  'chai',
#  'kulfi',
#  'jalebi',
#  'kaathi_rolls',
#  'dhokla',
#  'paani_puri',
#  'chapati',
#  'burger',
#  'idli',
#  'kadai_paneer',
#  'dal_makhani',
#  'butter_naan',
#  'kadai_paneer',
#  'pizza',
#  'pakode',
#  'momos',
#  'dal_makhani',
#  'kaathi_rolls',
#  'chapati',
#  'pakode',
#  'chapati',
#  'butter_naan',
# ...

# %%
def output(location):
  img=load_img(location,target_size=(224,224,3))
  img=img_to_array(img)
  img=img/255
  img=np.expand_dims(img,[0])
  answer=model.predict(img)
  y_class=answer.argmax(axis=-1)
  y=" ".join(str(x) for x in y_class)
  y=int(y)
  res=labels[y]
  return res

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import cv2



test_img= cv2.imread("/content/dosa.jpeg")
plt.imshow(test_img)
test_img=cv2.resize(test_img,(64,64))
test_image = image.load_img('/content/dosa.jpeg', target_size = (64,64))
test_image = image.img_to_array(test_image)
test_image=test_image/255
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_images)
result

predicted_food=output("/content/dosa.jpeg")

calories_dict = {
    'kaathi_rolls': 300,
    'samosa': 150,
    'momos': 100,
    'kadai_paneer': 350,
    'idli': 60,
    'fried_rice': 400,
    'chapati': 80,
    'burger': 250,
    'dal_makhani': 350,
    'jalebi': 250,
    'pizza': 300,
    'chai': 50,
    'chole_bhature': 450,
    'pakode': 200,
    'pav_bhaji': 350,
    'butter_naan': 200,
    'paani_puri': 100,
    'kulfi': 200,
    'masala_dosa': 350,
    'dhokla': 150
}

cal=calories_dict[predicted_food]
print(f"{predicted_food} has approximately {cal} calories per serving. ")
# Out:
# ...
# 1/1 [==============================] - 0s 56ms/step
# masala_dosa has approximately 350 calories per serving.
